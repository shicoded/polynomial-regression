# %% [markdown]
# <a href="https://colab.research.google.com/github/shicoded/polynomial-regression/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate X values
X = np.linspace(-5, 5, 100)

# Generate Y values with quadratic relationship
Y = 2 * X**2 + 3 * X + 5 + np.random.normal(0, 5, 100)

plt.scatter(X, Y, label='Data points')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Synthetic Data with Quadratic Relationship')
plt.legend()
plt.show()

# %%
# Create polynomial features (degree 2)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X.reshape(-1, 1))

# Fit linear regression model to the polynomial features
model = LinearRegression()
model.fit(X_poly, Y)

# Predict Y values using the fitted model
Y_pred = model.predict(X_poly)

# Plot the synthetic data points and the fitted polynomial curve
plt.scatter(X, Y, label='Data points')
plt.plot(X, Y_pred, color='red', label='Fitted polynomial curve')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Regression Fit (Degree 2)')
plt.legend()
plt.show()

# Print the model coefficients
print("Model Coefficients:", model.coef_)
print("Model Intercept:", model.intercept_)
# Out:
# Model Coefficients: [0.         3.01008515 1.94083175]
# Model Intercept: 5.614552631466047
